# %% [markdown]
# # Laboratory of Computational Physics Mod. A - Pylab 05
#
# ## Student
#
# Luca Menti
#
# ## ID
#
# 2063594
#
#
# ## Email
#
# luca.menti@studenti.unipd.it
#
# ## Course
#
# Physics of Data

# %% [markdown]
# # Exercise 1
#
# ### 1. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
# using random.sample()
# to generate random number list
res = random.sample(range(1, 50), 7)
 
# printing result
print ("Random number list is : " +  str(res))

with open("random.txt", "w") as output:
    output.write(str(res))
# Out:
# Random number list is : [37, 21, 38, 35, 4, 13, 7]

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ### 2. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
matrix=np.random.rand(5,5)
print(matrix)

with open("data.txt", "w") as output:
    output.write(str(matrix))
# Out:
# [[0.26821708 0.87569486 0.64226273 0.96620657 0.89086323]
#  [0.65504579 0.88113945 0.06794504 0.25626138 0.41772939]
#  [0.57363767 0.8914456  0.8726056  0.38933865 0.12688116]
#  [0.43684859 0.02425137 0.02296357 0.06564266 0.92812669]
#  [0.89553257 0.46156681 0.76314986 0.90353432 0.36028591]]

# %% [markdown]
# # Exercise 3
#
# ### 3. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
#read txt file
df = pd.read_fwf('data.txt')
print(df)

#convert to csv
df.to_csv('data.csv')
df
# Out:
#   [[0.26821708  0.87569486  0.64226273  0.96620657   0.89086323]
# 0  [0.65504579    0.881139    0.067945    0.256261   0.41772939]
# 1  [0.57363767    0.891446    0.872606    0.389339   0.12688116]
# 2  [0.43684859    0.024251    0.022964    0.065643   0.92812669]
# 3  [0.89553257    0.461567    0.763150    0.903534  0.36028591]]
#   [[0.26821708  0.87569486  0.64226273  0.96620657   0.89086323]
# 0  [0.65504579    0.881139    0.067945    0.256261   0.41772939]
# 1  [0.57363767    0.891446    0.872606    0.389339   0.12688116]
# 2  [0.43684859    0.024251    0.022964    0.065643   0.92812669]
# 3  [0.89553257    0.461567    0.763150    0.903534  0.36028591]]

# %% [markdown]
# # Exercise 4
#
# ### 4. load the binary file named credit_card.dat and convert the data into the real credit-card number. Each line correspond to a credit card number. Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding

# %%
import struct
from array import array

with  open('credit_card.dat','rb') as file:
    file_content=file.read()

#transform the file into array    
array="".join(map(chr, file_content ))
#divide di array into array of elements corresponding each lines
arr = array.split()


#function to join elements of list into a string
def convert(list):
     
    # Converting integer list to string list
    s = [str(i) for i in list]
     
    # Join list items using join()
    res = str("".join(s))
     
    return(res)


#loop to convert each number in list into ASCII
N=6
cc=[]
for i in range(len(arr)):
    theList = list(map(int, str(arr[i])))
    subList = [theList[n:n+N] for n in range(0, len(theList), N)]
    for j in range(len(subList)):
        y=convert(subList[j])
        decimal_number = int(y,2)
        decimal_number=chr(decimal_number)
        cc.append(decimal_number)

        

del cc[20-1::20]
for i in range(0, len(cc), 19):
    print(cc[i:i+step])
# Out:
# ['7', '6', '4', '8', ' ', '5', '6', '7', '3', ' ', '3', '7', '7', '5', ' ', '2', '2', '7', '1']
# ['3', '2', '5', '7', ' ', '8', '2', '4', '7', ' ', '3', '3', '5', '4', ' ', '2', '2', '6', '6']
# ['2', '7', '2', '2', ' ', '0', '0', '0', '1', ' ', '4', '0', '1', '1', ' ', '6', '6', '5', '2']
# ['0', '6', '6', '1', ' ', '3', '0', '6', '3', ' ', '3', '7', '4', '2', ' ', '3', '1', '5', '0']
# ['0', '4', '3', '2', ' ', '1', '6', '0', '8', ' ', '1', '4', '6', '2', ' ', '4', '7', '4', '2']
# ['5', '8', '2', '7', ' ', '2', '0', '2', '7', ' ', '8', '7', '8', '5', ' ', '7', '3', '0', '3']
# ['5', '7', '7', '4', ' ', '8', '5', '2', '8', ' ', '2', '0', '8', '7', ' ', '1', '1', '1', '7']
# ['8', '1', '4', '0', ' ', '1', '2', '1', '0', ' ', '6', '3', '5', '2', ' ', '2', '8', '4', '5']
# ['5', '7', '6', '4', ' ', '1', '1', '3', '3', ' ', '7', '3', '0', '1', ' ', '7', '1', '0', '0']
# ['6', '4', '5', '6', ' ', '1', '7', '3', '7', ' ', '4', '1', '2', '6', ' ', '6', '7', '2', '6']
# ...

# %% [markdown]
# # Exercise 5
#
# ### 5. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
#load
data = json.load(open('user_data.json'))

#filter 
data=[obj for obj in data if(obj['CreditCardType'] == "American Express")] 


df = pd.DataFrame(data) 


# saving the dataframe 
df.to_csv('Credit_American.csv')

#print df
df
# Out:
#      ID               JobTitle                       EmailAddress  \
# 0     2    Investment  Advisor       Clint_Thorpe5003@bulaffy.com
# 1    12         Retail Trainee   Phillip_Carpenter9505@famism.biz
# 2    28        Project Manager        Russel_Graves1378@extex.org
# 3    39            Stockbroker       Leanne_Newton1268@typill.biz
# 4    57         Budget Analyst          Tony_Giles1960@iatim.tech
# 5    62           CNC Operator        Owen_Allcott5125@bauros.biz
# 6    68        Project Manager           Liam_Lynn3280@kideod.biz
# 7    74                Dentist      Regina_Woodcock5820@yahoo.com
# 8    81          HR Specialist       Carter_Wallace9614@atink.com
# 9    92    Staffing Consultant           Maia_Stark2797@jiman.org
# 10   97            Stockbroker          Ciara_Lomax982@bauros.biz
# 11  116    Staffing Consultant      Isabel_Ellwood1475@fuliss.net
# 12  148           CNC Operator  Abdul_Townend2202@infotech44.tech
# ...

# %% [markdown]
# # Exercise 6
#
# ### 6. Load the file from this url: https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1 with Pandas.
#
# ### - Explore the data (see the info of the data)
#
# ### -Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
#import the file

url="https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
c=pd.read_csv(url)
c
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
#histogram
c=c['class']
plt.hist(c)
plt.title("Class hist")
# Out:
# Text(0.5, 1.0, 'Class hist')

# %% [markdown]
# # Exercise 7
#
# ### 7. Load the remote file https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1 with Pandas and plot a scatter plot all possible combination of the following fields:
#
# ### - features 1
#
# ### - features 2
#
# ### - features 3

# %%
url="https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1"
c=pd.read_csv(url)
c
# Out:
#            label  features_1  features_2  features_3  features_4  features_5  \
# 0     -89.243497    2.175170   -0.285786   -0.603396   -0.627453   -0.686474
# 1     230.050125    1.481941   -1.327870   -0.543583   -0.303578    1.552964
# 2    -286.844411   -1.154394   -0.178649   -1.636646    0.239353   -0.684994
# 3     364.552862    0.197665    1.455707    1.562205    2.168207    0.053335
# 4     515.460006    0.596676    0.969860    1.294158   -0.404728    2.145297
# ...          ...         ...         ...         ...         ...         ...
# 1995 -328.100239   -1.820929    1.358539   -2.494838    0.828299    0.199255
# 1996  -62.960036   -0.883712   -0.063687   -0.418704   -0.872601    0.363769
# 1997  -90.262252   -0.021394   -0.312864   -0.730848   -1.341482   -0.720862
# 1998  -74.333901   -0.041909   -0.862731   -1.232011    1.268843    0.093043
# 1999    8.321454   -1.056364    0.259247    0.307835    1.094903    0.472395
#
# ...

# %%
plt.rcParams["figure.figsize"] = (10,6)

plt.subplot(2,2,1)
plt.scatter(c["features_1"],c["features_2"],c='r')
plt.title('A simple scatter plot')
plt.xlabel('feat 1')
plt.ylabel('feat 2')
plt.grid()

plt.subplot(2,2,2)
plt.scatter(c["features_2"],c["features_1"],c='b')
plt.title('A simple scatter plot')
plt.xlabel('feat 2')
plt.ylabel('feat 1')
plt.grid()

plt.subplot(2,2,3)
plt.scatter(c["features_2"],c["features_3"],c='g')

plt.xlabel('feat 2')
plt.ylabel('feat 3')
plt.grid()

plt.subplot(2,2,4)
plt.scatter(c["features_3"],c["features_2"],c='y')

plt.xlabel('feat 3')
plt.ylabel('feat 2')
plt.grid()

# %%
plt.subplot(2,2,1)
plt.scatter(c["features_1"],c["features_3"],c='orange')
plt.title('A simple scatter plot')
plt.xlabel('feat 1')
plt.ylabel('feat 3')
plt.grid()

plt.subplot(2,2,2)
plt.scatter(c["features_3"],c["features_1"],c='black')
plt.title('A simple scatter plot')
plt.xlabel('feat 3')
plt.ylabel('feat 1')
plt.grid()

# %% [markdown]
# # Exercise 8
#
# ### 8. Load the same file of point 6, and convert the file to json with Pandas.

# %%
#import the file

url="https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
c=pd.read_csv(url)
c
#convert
c.to_json("c.json")

#reconvert to check
data=pd.read_json("c.json")
data
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...
